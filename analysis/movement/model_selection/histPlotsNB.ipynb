# %%
from matplotlib import pylab as plt
import matplotlib
import numpy as np
from scipy.stats import norm
#%matplotlib notebook
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 16})

# %%
rho_m = np.load('mc_data/crw_rho_m.npy')

plt.hist(rho_m,normed=True,range=[0.9250,0.945],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.9250,0.945)
plt.xlabel(r'$\rho$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.9250, 0.946,0.005))
plt.tight_layout()
plt.savefig("crw.tiff",bbox_inches='tight',dpi=300)
plt.savefig("crw.png",bbox_inches='tight',dpi=300)


plt.show()
print('rho_m mean: ' + str(np.mean(rho_m)) + ' sd: ' + str(np.std(rho_m)))
print('rho_m 95% CI : ' + str(np.percentile(rho_m,2.5)) + ',' + str(np.percentile(rho_m,97.5)))
# Out:
# rho_m mean: 0.932431995556 sd: 0.000637695840813
# rho_m 95% CI : 0.931179120747,0.933674850095

# %%
rho_m = np.load('mc_data/env_rho_m.npy')
beta = np.load('mc_data/env_beta.npy')


plt.hist(rho_m,normed=True,range=[0.925,0.945],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
#plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

plt.xlim(0.925,0.945)
plt.xlabel(r'$\rho$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.9250, 0.946,0.005))
plt.tight_layout()
plt.savefig('env_rho.png',dpi=300)
plt.savefig('env_rho.tiff',dpi=300)
plt.show()
print('rho_m mean: ' + str(np.mean(rho_m)) + ' sd: ' + str(np.std(rho_m)))
print('rho_m 95% CI : ' + str(np.percentile(rho_m,2.5)) + ',' + str(np.percentile(rho_m,97.5)))

plt.hist(beta,normed=True,range=[0.12,0.19],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
#plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

plt.xlim(0.12, 0.19)
plt.xlabel(r'$\beta$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.12, 0.191,0.01))
plt.tight_layout()
plt.savefig('env_beta.png',dpi=300)
plt.savefig('env_beta.tiff',dpi=300)
plt.show()
print('beta mean: ' + str(np.mean(beta)) + ' sd: ' + str(np.std(beta)))
print('beta 95% CI : ' + str(np.percentile(beta,2.5)) + ',' + str(np.percentile(beta,97.5)))
# Out:
# rho_m mean: 0.93566304066 sd: 0.000605239891368
# rho_m 95% CI : 0.934470622017,0.93683534356
# beta mean: 0.157427677874 sd: 0.00390496931619
# beta 95% CI : 0.149787895452,0.165069796245

# %%
rho_m=np.load('mc_data/cm_rho_s.npy')
alpha=np.load('mc_data/cm_alpha.npy')
betap=np.load('mc_data/cm_beta.npy')

beta = (1-alpha)*betap
gamma = (1-alpha)*(1-betap)

ia = 2*np.load('mc_data/cm_ia.npy')
il = np.load('mc_data/cm_il.npy')
ig = np.load('mc_data/cm_ig.npy')


plt.hist(rho_m,normed=True,range=[0.930,0.945],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
#plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

plt.xlim(0.930,0.945)
plt.xlabel(r'$\rho$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.930, 0.946,0.005))
plt.tight_layout()
plt.savefig('cm_rho.png',dpi=300)
plt.savefig('cm_rho.tiff',dpi=300)
plt.show()

plt.hist(gamma,normed=True,range=[0.5,0.6],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.5,0.6)
plt.xlabel(r'$\gamma$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.5, 0.61,0.02))
plt.tight_layout()
plt.savefig('cm_gamma.png',dpi=300)
plt.savefig('cm_gamma.tiff',dpi=300)
plt.show()

plt.hist(beta,normed=True,range=[0.05,0.15],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.05,0.15)
plt.xlabel(r'$\beta$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.05, 0.151,0.02))
plt.tight_layout()
plt.savefig('cm_beta.png',dpi=300)
plt.savefig('cm_beta.tiff',dpi=300)
plt.show()

plt.hist(alpha,normed=True,range=[0.3,0.4],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.3, 0.4)
plt.xlabel(r'$\alpha$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.3, 0.41,0.02))
plt.tight_layout()
plt.savefig('cm_alpha.png',dpi=300)
plt.savefig('cm_alpha.tiff',dpi=300)
plt.show()


plt.hist(il,normed=True,range=[10,10.5],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(10, 10.5)
plt.xlabel('interaction length')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(10, 10.51,0.1))
plt.tight_layout()
plt.savefig('cm_il.png',dpi=300)
plt.savefig('cm_il.tiff',dpi=300)
plt.show()





plt.hist(ia,normed=True,range=[0.48,0.52],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.48, 0.52)
plt.xlabel('interaction angle')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.48, 0.521,0.02))
plt.tight_layout()
plt.savefig('cm_ia.png',dpi=300)
plt.savefig('cm_ia.tiff',dpi=300)
plt.show()



plt.hist(ig,normed=True,range=[0.9,1.75],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.9,1.75)
plt.xlabel('minimum interaction range')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.9, 1.75,0.25))
plt.tight_layout()
plt.savefig('cm_ig.png',dpi=300)
plt.savefig('cm_ig.tiff',dpi=300)
plt.show()


print('rho_m mean: ' + str(np.mean(rho_m)) + ' sd: ' + str(np.std(rho_m)))
print('rho_m 95% CI : ' + str(np.percentile(rho_m,2.5)) + ',' + str(np.percentile(rho_m,97.5)))

print('gamma mean: ' + str(np.mean(gamma)) + ' sd: ' + str(np.std(gamma)))
print('gamma 95% CI : ' + str(np.percentile(gamma,2.5)) + ',' + str(np.percentile(gamma,97.5)))

print('beta mean: ' + str(np.mean(beta)) + ' sd: ' + str(np.std(beta)))
print('beta 95% CI : ' + str(np.percentile(beta,2.5)) + ',' + str(np.percentile(beta,97.5)))

print('alpha mean: ' + str(np.mean(alpha)) + ' sd: ' + str(np.std(alpha)))
print('alpha 95% CI : ' + str(np.percentile(alpha,2.5)) + ',' + str(np.percentile(alpha,97.5)))

print('length mean: ' + str(np.mean(il)) + ' sd: ' + str(np.std(il)))
print('length 95% CI : ' + str(np.percentile(il,2.5)) + ',' + str(np.percentile(il,97.5)))

print('angle mean: ' + str(np.mean(ia)) + ' sd: ' + str(np.std(ia)))
print('angle 95% CI : ' + str(np.percentile(ia,2.5)) + ',' + str(np.percentile(ia,97.5)))

print('ignore mean: ' + str(np.mean(ig)) + ' sd: ' + str(np.std(ig)))
print('ignore 95% CI : ' + str(np.percentile(ig,2.5)) + ',' + str(np.percentile(ig,97.5)))
# Out:
# rho_m mean: 0.939432122611 sd: 0.00057664446537
# rho_m 95% CI : 0.938293478156,0.940570887384
# gamma mean: 0.552884962001 sd: 0.00791211726347
# gamma 95% CI : 0.537340802171,0.568410375449
# beta mean: 0.0902743785942 sd: 0.00310938087092
# beta 95% CI : 0.0842368222155,0.0964404484779
# alpha mean: 0.356840659405 sd: 0.00914145373842
# alpha 95% CI : 0.338835364312,0.37480500356
# length mean: 10.1457081783 sd: 0.0207607230836
# length 95% CI : 10.1228113898,10.19027554
# angle mean: 0.503172520662 sd: 0.000752581282477
# angle 95% CI : 0.501080165476,0.503713601696
# ignore mean: 1.31564693726 sd: 0.0321837637879
# ignore 95% CI : 1.23418165808,1.36989737246

# %%
rho_m=np.load('mc_data/cma_rho_s.npy')
alpha=np.load('mc_data/cma_alpha.npy')
betap=np.load('mc_data/cma_beta.npy')

beta = (1-alpha)*betap
gamma = (1-alpha)*(1-betap)

ia = 2*np.load('mc_data/cma_at_a.npy')
il = np.load('mc_data/cma_at_l.npy')
ig = np.load('mc_data/cma_ig.npy')
aw = np.load('mc_data/cma_aw.npy')


plt.hist(rho_m,normed=True,range=[0.930,0.945],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
#plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

plt.xlim(0.930,0.945)
plt.xlabel(r'$\rho$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.930, 0.946,0.005))
plt.tight_layout()
plt.savefig('cma_rho.png',dpi=300)
plt.savefig('cma_rho.tiff',dpi=300)
plt.show()

plt.hist(gamma,normed=True,range=[0.5,0.6],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.5,0.6)
plt.xlabel(r'$\gamma$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.5, 0.61,0.02))
plt.tight_layout()
plt.savefig('cma_gamma.png',dpi=300)
plt.savefig('cma_gamma.tiff',dpi=300)
plt.show()

plt.hist(beta,normed=True,range=[0.05,0.15],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.05,0.15)
plt.xlabel(r'$\beta$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.05, 0.151,0.02))
plt.tight_layout()
plt.savefig('cma_beta.png',dpi=300)
plt.savefig('cma_beta.tiff',dpi=300)
plt.show()

plt.hist(alpha,normed=True,range=[0.32,0.42],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.32, 0.42)
plt.xlabel(r'$\alpha$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.32, 0.421,0.02))
plt.tight_layout()
plt.savefig('cma_alpha.png',dpi=300)
plt.savefig('cma_alpha.tiff',dpi=300)
plt.show()


plt.hist(il,normed=True,range=[10,10.5],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(10, 10.5)
plt.xlabel('interaction length')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(10, 10.51,0.1))
plt.tight_layout()
plt.savefig('cma_il.png',dpi=300)
plt.savefig('cma_il.tiff',dpi=300)
plt.show()





plt.hist(ia,normed=True,range=[0.48,0.52],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.48, 0.52)
plt.xlabel('interaction angle')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.48, 0.521,0.02))
plt.tight_layout()
plt.savefig('cma_ia.png',dpi=300)
plt.savefig('cma_ia.tiff',dpi=300)
plt.show()

plt.hist(aw,normed=True,range=[0.0,1],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.0,1)
plt.xlabel('align weight')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.0, 1.01,0.1))
plt.tight_layout()
plt.savefig('cma_aw.png',dpi=300)
plt.savefig('cma_aw.tiff',dpi=300)
plt.show()
print('align mean: ' + str(np.mean(aw)) + ' sd: ' + str(np.std(aw)))
print('align 95% CI : ' + str(np.percentile(aw,2.5)) + ',' + str(np.percentile(aw,97.5)))

print('rho_m mean: ' + str(np.mean(rho_m)) + ' sd: ' + str(np.std(rho_m)))
print('rho_m 95% CI : ' + str(np.percentile(rho_m,2.5)) + ',' + str(np.percentile(rho_m,97.5)))


print('gamma mean: ' + str(np.mean(gamma)) + ' sd: ' + str(np.std(gamma)))
print('gamma 95% CI : ' + str(np.percentile(gamma,2.5)) + ',' + str(np.percentile(gamma,97.5)))

print('beta mean: ' + str(np.mean(beta)) + ' sd: ' + str(np.std(beta)))
print('beta 95% CI : ' + str(np.percentile(beta,2.5)) + ',' + str(np.percentile(beta,97.5)))

print('alpha mean: ' + str(np.mean(alpha)) + ' sd: ' + str(np.std(alpha)))
print('alpha 95% CI : ' + str(np.percentile(alpha,2.5)) + ',' + str(np.percentile(alpha,97.5)))

print('length mean: ' + str(np.mean(il)) + ' sd: ' + str(np.std(il)))
print('length 95% CI : ' + str(np.percentile(il,2.5)) + ',' + str(np.percentile(il,97.5)))

print('angle mean: ' + str(np.mean(ia)) + ' sd: ' + str(np.std(ia)))
print('angle 95% CI : ' + str(np.percentile(ia,2.5)) + ',' + str(np.percentile(ia,97.5)))

print('ignore mean: ' + str(np.mean(ig)) + ' sd: ' + str(np.std(ig)))
print('ignore 95% CI : ' + str(np.percentile(ig,2.5)) + ',' + str(np.percentile(ig,97.5)))
# Out:
# align mean: 0.573414186481 sd: 0.0868541849779
# align 95% CI : 0.405898143798,0.743661967529
# rho_m mean: 0.939465197509 sd: 0.000573904461979
# rho_m 95% CI : 0.938340388102,0.940596196789
# gamma mean: 0.542886385012 sd: 0.00798981339138
# gamma 95% CI : 0.527324508927,0.558551942885
# beta mean: 0.0859281146867 sd: 0.00307525041417
# beta 95% CI : 0.0799894326473,0.09201789247
# alpha mean: 0.371185500302 sd: 0.00926775008554
# alpha 95% CI : 0.353078011982,0.389340198153
# length mean: 10.1269530752 sd: 0.0771523388603
# length 95% CI : 9.84688592124,10.1933473569
# angle mean: 0.50339111148 sd: 0.00100372746801
# angle 95% CI : 0.501063112434,0.505238527578
# ignore mean: 1.30018863097 sd: 0.0439000712332
# ignore 95% CI : 1.2203634794,1.37221455139

# %%
rho_s=np.load('mc_data/dm_rho_s.npy')
alpha=np.load('mc_data/dm_alpha.npy')
betap=np.load('mc_data/dm_beta.npy')

beta = (1-alpha)*betap
gamma = (1-alpha)*(1-betap)

ia = 2*np.load('mc_data/dm_ia.npy')
il = np.load('mc_data/dm_il.npy')
de = np.load('mc_data/dm_de.npy')
ig = np.load('mc_data/dm_ig.npy')



plt.hist(rho_s,normed=True,range=[0.930,0.945],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
#plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

plt.xlim(0.930,0.945)
plt.xlabel(r'$\rho$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.930, 0.946,0.005))
plt.tight_layout()
plt.savefig('dm_rho.png',dpi=300)
plt.savefig('dm_rho.tiff',dpi=300)
plt.show()

plt.hist(gamma,normed=True,range=[0.5,0.6],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.5,0.6)
plt.xlabel(r'$\gamma$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.5, 0.61,0.02))
plt.tight_layout()
plt.savefig('dm_gamma.png',dpi=300)
plt.savefig('dm_gamma.tiff',dpi=300)
plt.show()

plt.hist(beta,normed=True,range=[0.05,0.15],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.05,0.15)
plt.xlabel(r'$\beta$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.05, 0.151,0.02))
plt.tight_layout()
plt.savefig('dm_beta.png',dpi=300)
plt.savefig('dm_beta.tiff',dpi=300)
plt.show()

plt.hist(alpha,normed=True,range=[0.3,0.4],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.3, 0.4)
plt.xlabel(r'$\alpha$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.3, 0.41,0.02))
plt.tight_layout()
plt.savefig('dm_alpha.png',dpi=300)
plt.savefig('dm_alpha.tiff',dpi=300)
plt.show()


plt.hist(il,normed=True,range=[6,10],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(6,10)
plt.xlabel('interaction length')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(6,10.1,1))
plt.tight_layout()
plt.savefig('dm_il.png',dpi=300)
plt.savefig('dm_il.tiff',dpi=300)
plt.show()





plt.hist(ia,normed=True,range=[0.48,0.52],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.48, 0.52)
plt.xlabel('interaction angle')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.48, 0.521,0.02))
plt.tight_layout()
plt.savefig('dm_ia.png',dpi=300)
plt.savefig('dm_ia.tiff',dpi=300)
plt.show()



plt.hist(ig,normed=True,range=[0.9,1.75],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.9,1.75)
plt.xlabel('minimum interaction range')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.9, 1.75,0.25))
plt.tight_layout()
plt.savefig('dm_ig.png',dpi=300)
plt.savefig('dm_ig.tiff',dpi=300)
plt.show()


plt.hist(de,normed=True,range=[5,25],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(5,25)
plt.xlabel('decay exponent')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(5.0, 25.01,2))
plt.tight_layout()
plt.savefig('dm_de.png',dpi=300)
plt.savefig('dm_de.tiff',dpi=300)
plt.show()


print('rho_s mean: ' + str(np.mean(rho_s)) + ' sd: ' + str(np.std(rho_s)))
print('rho_s 95% CI : ' + str(np.percentile(rho_s,2.5)) + ',' + str(np.percentile(rho_s,97.5)))

print('gamma mean: ' + str(np.mean(gamma)) + ' sd: ' + str(np.std(gamma)))
print('gamma 95% CI : ' + str(np.percentile(gamma,2.5)) + ',' + str(np.percentile(gamma,97.5)))

print('beta mean: ' + str(np.mean(beta)) + ' sd: ' + str(np.std(beta)))
print('beta 95% CI : ' + str(np.percentile(beta,2.5)) + ',' + str(np.percentile(beta,97.5)))

print('alpha mean: ' + str(np.mean(alpha)) + ' sd: ' + str(np.std(alpha)))
print('alpha 95% CI : ' + str(np.percentile(alpha,2.5)) + ',' + str(np.percentile(alpha,97.5)))

print('length mean: ' + str(np.mean(il)) + ' sd: ' + str(np.std(il)))
print('length 95% CI : ' + str(np.percentile(il,2.5)) + ',' + str(np.percentile(il,97.5)))

print('angle mean: ' + str(np.mean(ia)) + ' sd: ' + str(np.std(ia)))
print('angle 95% CI : ' + str(np.percentile(ia,2.5)) + ',' + str(np.percentile(ia,97.5)))

print('ignore mean: ' + str(np.mean(ig)) + ' sd: ' + str(np.std(ig)))
print('ignore 95% CI : ' + str(np.percentile(ig,2.5)) + ',' + str(np.percentile(ig,97.5)))

print('decay mean: ' + str(np.mean(de)) + ' sd: ' + str(np.std(de)))
print('decay 95% CI : ' + str(np.percentile(de,2.5)) + ',' + str(np.percentile(de,97.5)))
# Out:
# rho_s mean: 0.939466116576 sd: 0.000578935263343
# rho_s 95% CI : 0.938339247083,0.940594617223
# gamma mean: 0.557198008348 sd: 0.00792130678111
# gamma 95% CI : 0.541762821208,0.572669759003
# beta mean: 0.0919637323531 sd: 0.0031731819443
# beta 95% CI : 0.0857989765204,0.0982289825752
# alpha mean: 0.350838259299 sd: 0.00919738571755
# alpha 95% CI : 0.332799444907,0.368877138582
# length mean: 7.97959570629 sd: 0.662125936646
# length 95% CI : 5.77169117811,8.57815056617
# angle mean: 0.502956866693 sd: 0.000803583961605
# angle 95% CI : 0.501038577421,0.503716374027
# ignore mean: 1.3257090876 sd: 0.0358772783379
# ignore 95% CI : 1.24965912718,1.37654900003
# decay mean: 19.0118664983 sd: 4.05724029982
# decay 95% CI : 8.13319250029,24.6481010758

# %%
rho_s=np.load('mc_data/dma_rho_s.npy')
alpha=np.load('mc_data/dma_alpha.npy')

betap=np.load('mc_data/dma_beta.npy')

beta = (1-alpha)*betap
gamma = (1-alpha)*(1-betap)

ia = 2*np.load('mc_data/dma_at_a.npy')
il = np.load('mc_data/dma_at_l.npy')
de = np.load('mc_data/dma_at_e.npy')
aw = np.load('mc_data/dma_aw.npy')
ig = np.load('mc_data/dma_ig.npy')


plt.hist(rho_s,normed=True,range=[0.930,0.945],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
#plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

plt.xlim(0.930,0.945)
plt.xlabel(r'$\rho$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.930, 0.946,0.005))
plt.tight_layout()
plt.savefig('dma_rho.png',dpi=300)
plt.show()
plt.hist(gamma,normed=True,range=[0.5,0.6],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.5,0.6)
plt.xlabel(r'$\gamma$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.5, 0.61,0.02))
plt.tight_layout()
plt.savefig('dma_gamma.png',dpi=300)
plt.savefig('dma_gamma.tiff',dpi=300)
plt.show()

plt.hist(beta,normed=True,range=[0.05,0.15],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.05,0.15)
plt.xlabel(r'$\beta$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.05, 0.151,0.02))
plt.tight_layout()
plt.savefig('dma_beta.png',dpi=300)
plt.savefig('dma_beta.tiff',dpi=300)
plt.show()
plt.hist(alpha,normed=True,range=[0.3,0.4],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.3, 0.4)
plt.xlabel(r'$\alpha$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.3, 0.41,0.02))
plt.tight_layout()
plt.savefig('dma_alpha.png',dpi=300)
plt.show()


plt.hist(il,normed=True,range=[2,7],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(2,7)
plt.xlabel('interaction length')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(2,7.1,1))
plt.tight_layout()
plt.savefig('dma_il.png',dpi=300)
plt.show()





plt.hist(ia,normed=True,range=[0.50,0.56],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.50, 0.56)
plt.xlabel('interaction angle')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.50, 0.561,0.02))
plt.tight_layout()
plt.savefig('dma_ia.png',dpi=300)
plt.show()



plt.hist(ig,normed=True,range=[0.9,1.75],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.9,1.75)
plt.xlabel('minimum interaction range')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.9, 1.75,0.25))
plt.tight_layout()
plt.savefig('dma_ig.png',dpi=300)
plt.show()


plt.hist(de,normed=True,range=[5,25],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(5,25)
plt.xlabel('decay exponent')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(5.0, 25.01,2))
plt.tight_layout()
plt.savefig('dma_de.png',dpi=300)
plt.show()


plt.hist(aw,normed=True,range=[0.0,1],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.0,1)
plt.xlabel('align weight')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.0, 1.01,0.1))
plt.tight_layout()
plt.savefig('dma_aw.png',dpi=300)
plt.show()
print('align mean: ' + str(np.mean(aw)) + ' sd: ' + str(np.std(aw)))
print('align 95% CI : ' + str(np.percentile(aw,2.5)) + ',' + str(np.percentile(aw,97.5)))

print('rho_s mean: ' + str(np.mean(rho_s)) + ' sd: ' + str(np.std(rho_s)))
print('rho_s 95% CI : ' + str(np.percentile(rho_s,2.5)) + ',' + str(np.percentile(rho_s,97.5)))

print('gamma mean: ' + str(np.mean(gamma)) + ' sd: ' + str(np.std(gamma)))
print('gamma 95% CI : ' + str(np.percentile(gamma,2.5)) + ',' + str(np.percentile(gamma,97.5)))

print('beta mean: ' + str(np.mean(beta)) + ' sd: ' + str(np.std(beta)))
print('beta 95% CI : ' + str(np.percentile(beta,2.5)) + ',' + str(np.percentile(beta,97.5)))

print('alpha mean: ' + str(np.mean(alpha)) + ' sd: ' + str(np.std(alpha)))
print('alpha 95% CI : ' + str(np.percentile(alpha,2.5)) + ',' + str(np.percentile(alpha,97.5)))

print('length mean: ' + str(np.mean(il)) + ' sd: ' + str(np.std(il)))
print('length 95% CI : ' + str(np.percentile(il,2.5)) + ',' + str(np.percentile(il,97.5)))

print('angle mean: ' + str(np.mean(ia)) + ' sd: ' + str(np.std(ia)))
print('angle 95% CI : ' + str(np.percentile(ia,2.5)) + ',' + str(np.percentile(ia,97.5)))

print('ignore mean: ' + str(np.mean(ig)) + ' sd: ' + str(np.std(ig)))
print('ignore 95% CI : ' + str(np.percentile(ig,2.5)) + ',' + str(np.percentile(ig,97.5)))

print('decay mean: ' + str(np.mean(de)) + ' sd: ' + str(np.std(de)))
print('decay 95% CI : ' + str(np.percentile(de,2.5)) + ',' + str(np.percentile(de,97.5)))
# Out:
# align mean: 0.767677947721 sd: 0.0848838388474
# align 95% CI : 0.617591253417,0.944907133239
# rho_s mean: 0.939645995306 sd: 0.000576306039088
# rho_s 95% CI : 0.938505435991,0.940758597956
# gamma mean: 0.531824442281 sd: 0.00858154892348
# gamma 95% CI : 0.515236515847,0.548942761588
# beta mean: 0.0842576941121 sd: 0.00303170602856
# beta 95% CI : 0.078390339689,0.0902540919948
# alpha mean: 0.383917863607 sd: 0.00988066117525
# alpha 95% CI : 0.364245443498,0.402969014132
# length mean: 5.0065566926 sd: 0.292495841017
# length 95% CI : 4.43563722814,5.54365519878
# angle mean: 0.552251198719 sd: 0.00222115982836
# angle 95% CI : 0.550401962893,0.561178395093
# ignore mean: 1.33000865474 sd: 0.0327430476419
# ignore 95% CI : 1.24783256818,1.3787812383
# decay mean: 9.16788235787 sd: 1.0933939574
# decay 95% CI : 7.30215028594,11.448540129

# %%
rho_s=np.load('mc_data/nm_rho_s.npy')
alpha=np.load('mc_data/nm_alpha.npy')
betap=np.load('mc_data/nm_beta.npy')

beta = (1-alpha)*betap
gamma = (1-alpha)*(1-betap)

ia = 2*np.load('mc_data/nm_ia.npy')
il = np.load('mc_data/nm_il.npy')
ig = np.load('mc_data/nm_ig.npy')



plt.hist(rho_s,normed=True,range=[0.930,0.945],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
#plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

plt.xlim(0.930,0.945)
plt.xlabel(r'$\rho$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.930, 0.946,0.005))
plt.tight_layout()
plt.savefig('nm_rho.png',dpi=300)
plt.show()

plt.hist(beta,normed=True,range=[0.05,0.15],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.05,0.15)
plt.xlabel(r'$\beta$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.05,0.151,0.01))
plt.tight_layout()
plt.savefig('nm_beta.png',dpi=300)
plt.show()

plt.hist(alpha,normed=True,range=[0.2,0.4],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.2, 0.4)
plt.xlabel(r'$\alpha$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.2, 0.41,0.02))
plt.tight_layout()
plt.savefig('nm_alpha.png',dpi=300)
plt.show()


vc = np.bincount(il,minlength=5)
vc = vc/sum(vc)
xax = np.arange(len(vc))
plt.stem(xax,vc, linefmt='b-', markerfmt='bo', basefmt='r-')
plt.xlim(0,4)
plt.ylim(0,1.5)
plt.xlabel('interaction length')
plt.ylabel('posterior probability mass')
plt.xticks(np.arange(0,4.1,1))
plt.tight_layout()
plt.savefig('nm_il.png',dpi=300)
plt.show()



plt.hist(ia,normed=True,range=[0.52,0.58],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.52,0.58)
plt.xlabel('interaction angle')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.52,0.581,0.01))
plt.tight_layout()
plt.savefig('nm_ia.png',dpi=300)
plt.show()



plt.hist(ig,normed=True,range=[0.9,1.75],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.9,1.75)
plt.xlabel('minimum interaction range')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.9, 1.75,0.25))
plt.tight_layout()
plt.savefig('nm_ig.png',dpi=300)
plt.show()



print('rho_s mean: ' + str(np.mean(rho_s)) + ' sd: ' + str(np.std(rho_s)))
print('rho_s 95% CI : ' + str(np.percentile(rho_s,2.5)) + ',' + str(np.percentile(rho_s,97.5)))

print('gamma mean: ' + str(np.mean(gamma)) + ' sd: ' + str(np.std(gamma)))
print('gamma 95% CI : ' + str(np.percentile(gamma,2.5)) + ',' + str(np.percentile(gamma,97.5)))

print('beta mean: ' + str(np.mean(beta)) + ' sd: ' + str(np.std(beta)))
print('beta 95% CI : ' + str(np.percentile(beta,2.5)) + ',' + str(np.percentile(beta,97.5)))

print('alpha mean: ' + str(np.mean(alpha)) + ' sd: ' + str(np.std(alpha)))
print('alpha 95% CI : ' + str(np.percentile(alpha,2.5)) + ',' + str(np.percentile(alpha,97.5)))

print('length mean: ' + str(np.mean(il)) + ' sd: ' + str(np.std(il)))
print('length 95% CI : ' + str(np.percentile(il,2.5)) + ',' + str(np.percentile(il,97.5)))

print('angle mean: ' + str(np.mean(ia)) + ' sd: ' + str(np.std(ia)))
print('angle 95% CI : ' + str(np.percentile(ia,2.5)) + ',' + str(np.percentile(ia,97.5)))

print('ignore mean: ' + str(np.mean(ig)) + ' sd: ' + str(np.std(ig)))
print('ignore 95% CI : ' + str(np.percentile(ig,2.5)) + ',' + str(np.percentile(ig,97.5)))
# Out:
# rho_s mean: 0.938627679335 sd: 0.000583845629599
# rho_s 95% CI : 0.937481071773,0.939771076436
# gamma mean: 0.663026760927 sd: 0.00628747355265
# gamma 95% CI : 0.650740034696,0.67541504482
# beta mean: 0.118190500795 sd: 0.00350915261815
# beta 95% CI : 0.111387229609,0.125095003959
# alpha mean: 0.218782738278 sd: 0.0065265705752
# alpha 95% CI : 0.205964116688,0.231594804101
# length mean: 1.0 sd: 0.0
# length 95% CI : 1.0,1.0
# angle mean: 0.563057045167 sd: 0.00408392748989
# angle 95% CI : 0.554196557578,0.568761247566
# ignore mean: 1.29284859317 sd: 0.0559395622308
# ignore 95% CI : 1.16168807002,1.36996049959

# %%
rho_s=np.load('mc_data/nma_rho_s.npy')
alpha=np.load('mc_data/nma_alpha.npy')

ia = 2*np.load('mc_data/nma_ia.npy')
il = np.load('mc_data/nma_il.npy')
aw = np.load('mc_data/nma_aw.npy')
ig = np.load('mc_data/nma_ig.npy')

betap=np.load('mc_data/nma_beta.npy')

beta = (1-alpha)*betap
gamma = (1-alpha)*(1-betap)


plt.hist(rho_s,normed=True,range=[0.930,0.945],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
#plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

plt.xlim(0.930,0.945)
plt.xlabel(r'$\rho$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.930, 0.946,0.005))
plt.tight_layout()
plt.savefig('nma_rho.png',dpi=300)
plt.show()

plt.hist(beta,normed=True,range=[0.05,0.15],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.05,0.15)
plt.xlabel(r'$\beta$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.05,0.151,0.01))
plt.tight_layout()
plt.savefig('nma_beta.png',dpi=300)
plt.show()

plt.hist(alpha,normed=True,range=[0.2,0.3],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.2, 0.3)
plt.xlabel(r'$\alpha$')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.2, 0.31,0.02))
plt.tight_layout()
plt.savefig('nma_alpha.png',dpi=300)
plt.show()



vc = np.bincount(il,minlength=5)
vc = vc/sum(vc)
xax = np.arange(len(vc))
plt.stem(xax,vc, linefmt='b-', markerfmt='bo', basefmt='r-')
plt.xlim(0,4)
plt.ylim(0,1.5)
plt.xlabel('interaction length')
plt.ylabel('posterior probability mass')
plt.xticks(np.arange(0,4.1,1))
plt.tight_layout()
plt.savefig('nma_il.png',dpi=300)
plt.show()



plt.hist(ia,normed=True,range=[0.54,0.58],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.54,0.58)
plt.xlabel('interaction angle')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.54,0.581,0.01))
plt.tight_layout()
plt.savefig('nma_ia.png',dpi=300)
plt.show()



plt.hist(ig,normed=True,range=[0.9,1.75],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.9,1.75)
plt.xlabel('minimum interaction range')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.9, 1.75,0.25))
plt.tight_layout()
plt.savefig('nma_ig.png',dpi=300)
plt.show()




plt.hist(aw,normed=True,range=[0.0,2],bins=60,histtype='stepfilled',color='midnightblue',alpha=0.9)
plt.xlim(0.0,2)
plt.xlabel('align weight')
plt.ylabel('posterior probability density')
plt.xticks(np.arange(0.0, 2.01,0.5))
plt.tight_layout()
plt.savefig('nma_aw.png',dpi=300)
plt.show()

print('align mean: ' + str(np.mean(aw)) + ' sd: ' + str(np.std(aw)))
print('align 95% CI : ' + str(np.percentile(aw,2.5)) + ',' + str(np.percentile(aw,97.5)))


print('rho_s mean: ' + str(np.mean(rho_s)) + ' sd: ' + str(np.std(rho_s)))
print('rho_s 95% CI : ' + str(np.percentile(rho_s,2.5)) + ',' + str(np.percentile(rho_s,97.5)))

print('gamma mean: ' + str(np.mean(gamma)) + ' sd: ' + str(np.std(gamma)))
print('gamma 95% CI : ' + str(np.percentile(gamma,2.5)) + ',' + str(np.percentile(gamma,97.5)))

print('beta mean: ' + str(np.mean(beta)) + ' sd: ' + str(np.std(beta)))
print('beta 95% CI : ' + str(np.percentile(beta,2.5)) + ',' + str(np.percentile(beta,97.5)))

print('alpha mean: ' + str(np.mean(alpha)) + ' sd: ' + str(np.std(alpha)))
print('alpha 95% CI : ' + str(np.percentile(alpha,2.5)) + ',' + str(np.percentile(alpha,97.5)))

print('length mean: ' + str(np.mean(il)) + ' sd: ' + str(np.std(il)))
print('length 95% CI : ' + str(np.percentile(il,2.5)) + ',' + str(np.percentile(il,97.5)))

print('angle mean: ' + str(np.mean(ia)) + ' sd: ' + str(np.std(ia)))
print('angle 95% CI : ' + str(np.percentile(ia,2.5)) + ',' + str(np.percentile(ia,97.5)))

print('ignore mean: ' + str(np.mean(ig)) + ' sd: ' + str(np.std(ig)))
print('ignore 95% CI : ' + str(np.percentile(ig,2.5)) + ',' + str(np.percentile(ig,97.5)))
# Out:
# align mean: 0.997873238031 sd: 0.12563688958
# align 95% CI : 0.756056340666,1.24989133155
# rho_s mean: 0.938706603646 sd: 0.000581309336936
# rho_s 95% CI : 0.93755672535,0.939835875482
# gamma mean: 0.653976082062 sd: 0.00619849867273
# gamma 95% CI : 0.641771078098,0.666204472034
# beta mean: 0.110241582113 sd: 0.00348980995155
# beta 95% CI : 0.103437278338,0.117101117461
# alpha mean: 0.235782335825 sd: 0.00659097473748
# alpha 95% CI : 0.222896055479,0.24877799323
# length mean: 1.0 sd: 0.0
# length 95% CI : 1.0,1.0
# angle mean: 0.567211396642 sd: 0.00253817909857
# angle 95% CI : 0.561577686319,0.56920399902
# ignore mean: 1.29417704376 sd: 0.0678027445345
# ignore 95% CI : 1.07529743163,1.36796753928
