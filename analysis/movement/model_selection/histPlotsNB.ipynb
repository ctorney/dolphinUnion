# %%
from matplotlib import pylab as plt
import matplotlib
import numpy as np
from scipy.stats import norm
#%matplotlib notebook
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 16})

# %%
rho_m = np.load('mc_data/crw_rho_m.npy')

plt.hist(rho_m,normed=True,range=[0.930,0.945],bins=60,alpha=0.8)

plt.xlim(0.930,0.945)
plt.xlabel(r'$\rho$')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.930, 0.946,0.005))
plt.tight_layout()
plt.savefig('crw.png',dpi=300)
plt.show()
print('rho_m mean: ' + str(np.mean(rho_m)) + ' sd: ' + str(np.std(rho_m)))
print('rho_m 95% CI : ' + str(np.percentile(rho_m,2.5)) + ',' + str(np.percentile(rho_m,97.5)))
# Out:
# rho_m mean: 0.932440749378 sd: 0.00064126566338
# rho_m 95% CI : 0.931171013509,0.933671977119

# %%
rho_m = np.load('mc_data/env_rho_m.npy')
beta = np.load('mc_data/env_beta.npy')


plt.hist(rho_m,normed=True,range=[0.930,0.945],bins=60,alpha=0.8)
#plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

plt.xlim(0.930,0.945)
plt.xlabel(r'$\rho$')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.930, 0.946,0.005))
plt.tight_layout()
plt.savefig('env_rho.png',dpi=300)
plt.show()
print('rho_m mean: ' + str(np.mean(rho_m)) + ' sd: ' + str(np.std(rho_m)))
print('rho_m 95% CI : ' + str(np.percentile(rho_m,2.5)) + ',' + str(np.percentile(rho_m,97.5)))

plt.hist(beta,normed=True,range=[0.075,0.15],bins=60,alpha=0.8)
#plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

plt.xlim(0.075, 0.15)
plt.xlabel(r'$\beta$')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.08, 0.16,0.01))
plt.tight_layout()
plt.savefig('env_beta.png',dpi=300)
plt.show()
print('beta mean: ' + str(np.mean(beta)) + ' sd: ' + str(np.std(beta)))
print('beta 95% CI : ' + str(np.percentile(beta,2.5)) + ',' + str(np.percentile(beta,97.5)))
# Out:
# rho_m mean: 0.933870256025 sd: 0.000621193279211
# rho_m 95% CI : 0.932685931904,0.93508157731
# beta mean: 0.107030809879 sd: 0.00347538947109
# beta 95% CI : 0.10039452785,0.11392308548

# %%
rho_m=np.load('mc_data/cm_rho_s.npy')
alpha=np.load('mc_data/cm_alpha.npy')
beta=np.load('mc_data/cm_beta.npy')

ia = np.load('mc_data/cm_ia.npy')
il = np.load('mc_data/cm_il.npy')
ig = np.load('mc_data/cm_ig.npy')


plt.hist(rho_m,normed=True,range=[0.930,0.945],bins=60,alpha=0.8)
#plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

plt.xlim(0.930,0.945)
plt.xlabel(r'$\rho$')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.930, 0.946,0.005))
plt.tight_layout()
plt.savefig('cm_rho.png',dpi=300)
plt.show()
print('rho_m mean: ' + str(np.mean(rho_m)) + ' sd: ' + str(np.std(rho_m)))
print('rho_m 95% CI : ' + str(np.percentile(rho_m,2.5)) + ',' + str(np.percentile(rho_m,97.5)))

plt.hist(beta,normed=True,range=[0.075,0.15],bins=60,alpha=0.8)
plt.xlim(0.075, 0.15)
plt.xlabel(r'$\beta$')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.08, 0.16,0.01))
plt.tight_layout()
plt.savefig('cm_beta.png',dpi=300)
plt.show()
print('beta mean: ' + str(np.mean(beta)) + ' sd: ' + str(np.std(beta)))
print('beta 95% CI : ' + str(np.percentile(beta,2.5)) + ',' + str(np.percentile(beta,97.5)))

plt.hist(alpha,normed=True,range=[0.3,0.5],bins=60,alpha=0.8)
plt.xlim(0.3, 0.5)
plt.xlabel(r'$\alpha$')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.3, 0.51,0.04))
plt.tight_layout()
plt.savefig('cm_alpha.png',dpi=300)
plt.show()
print('alpha mean: ' + str(np.mean(alpha)) + ' sd: ' + str(np.std(alpha)))
print('alpha 95% CI : ' + str(np.percentile(alpha,2.5)) + ',' + str(np.percentile(alpha,97.5)))


plt.hist(il,normed=True,range=[8,9.5],bins=60,alpha=0.8)
plt.xlim(8, 9.5)
plt.xlabel('interaction length')
plt.ylabel('posterior density')
plt.xticks(np.arange(8, 9.51,0.5))
plt.tight_layout()
plt.savefig('cm_il.png',dpi=300)
plt.show()
print('length mean: ' + str(np.mean(il)) + ' sd: ' + str(np.std(il)))
print('length 95% CI : ' + str(np.percentile(il,2.5)) + ',' + str(np.percentile(il,97.5)))


plt.hist(ia,normed=True,range=[0.26,0.29],bins=60,alpha=0.8)
plt.xlim(0.26, 0.29)
plt.xlabel('interaction angle')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.26, 0.291,0.01))
plt.tight_layout()
plt.savefig('cm_ia.png',dpi=300)
plt.show()
print('angle mean: ' + str(np.mean(ia)) + ' sd: ' + str(np.std(ia)))
print('angle 95% CI : ' + str(np.percentile(ia,2.5)) + ',' + str(np.percentile(ia,97.5)))


plt.hist(ig,normed=True,range=[0.9,1.75],bins=60,alpha=0.8)
plt.xlim(0.9,1.75)
plt.xlabel('minimum interaction range')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.9, 1.75,0.25))
plt.tight_layout()
plt.savefig('cm_ig.png',dpi=300)
plt.show()
print('ignore mean: ' + str(np.mean(ig)) + ' sd: ' + str(np.std(ig)))
print('ignore 95% CI : ' + str(np.percentile(ig,2.5)) + ',' + str(np.percentile(ig,97.5)))
# Out:
# rho_m mean: 0.93829301544 sd: 0.000586828183392
# rho_m 95% CI : 0.937116311456,0.939402127179
# beta mean: 0.094588947694 sd: 0.00373973384747
# beta 95% CI : 0.087197778838,0.102035631335
# alpha mean: 0.381391146065 sd: 0.00909992205401
# alpha 95% CI : 0.363215817896,0.399362901709
# length mean: 8.78401778463 sd: 0.0596229245848
# length 95% CI : 8.72923046962,8.88617219784
# angle mean: 0.276826224342 sd: 0.00140748171868
# angle 95% CI : 0.275317895927,0.280816828066
# ignore mean: 1.33541734941 sd: 0.0380579663918
# ignore 95% CI : 1.24272982867,1.39820917704

# %%
rho_m=np.load('mc_data/cma_rho_s.npy')
alpha=np.load('mc_data/cma_alpha.npy')
beta=np.load('mc_data/cma_beta.npy')

ia = np.load('mc_data/cma_at_a.npy')
il = np.load('mc_data/cma_at_l.npy')
ig = np.load('mc_data/cma_ig.npy')
aw = np.load('mc_data/cma_aw.npy')


plt.hist(rho_m,normed=True,range=[0.930,0.945],bins=60,alpha=0.8)
#plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

plt.xlim(0.930,0.945)
plt.xlabel(r'$\rho$')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.930, 0.946,0.005))
plt.tight_layout()
plt.savefig('cm_rho.png',dpi=300)
plt.show()
print('rho_m mean: ' + str(np.mean(rho_m)) + ' sd: ' + str(np.std(rho_m)))
print('rho_m 95% CI : ' + str(np.percentile(rho_m,2.5)) + ',' + str(np.percentile(rho_m,97.5)))

plt.hist(beta,normed=True,range=[0.065,0.14],bins=60,alpha=0.8)
plt.xlim(0.065, 0.14)
plt.xlabel(r'$\beta$')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.07, 0.15,0.01))
plt.tight_layout()
plt.savefig('cm_beta.png',dpi=300)
plt.show()
print('beta mean: ' + str(np.mean(beta)) + ' sd: ' + str(np.std(beta)))
print('beta 95% CI : ' + str(np.percentile(beta,2.5)) + ',' + str(np.percentile(beta,97.5)))

plt.hist(alpha,normed=True,range=[0.3,0.5],bins=60,alpha=0.8)
plt.xlim(0.3, 0.5)
plt.xlabel(r'$\alpha$')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.3, 0.51,0.04))
plt.tight_layout()
plt.savefig('cm_alpha.png',dpi=300)
plt.show()
print('alpha mean: ' + str(np.mean(alpha)) + ' sd: ' + str(np.std(alpha)))
print('alpha 95% CI : ' + str(np.percentile(alpha,2.5)) + ',' + str(np.percentile(alpha,97.5)))


plt.hist(il,normed=True,range=[8,9.5],bins=60,alpha=0.8)
plt.xlim(8, 9.5)
plt.xlabel('interaction length')
plt.ylabel('posterior density')
plt.xticks(np.arange(8, 9.51,0.5))
plt.tight_layout()
plt.savefig('cm_il.png',dpi=300)
plt.show()
print('length mean: ' + str(np.mean(il)) + ' sd: ' + str(np.std(il)))
print('length 95% CI : ' + str(np.percentile(il,2.5)) + ',' + str(np.percentile(il,97.5)))


plt.hist(ia,normed=True,range=[0.34,0.37],bins=60,alpha=0.8)
plt.xlim(0.34, 0.37)
plt.xlabel('interaction angle')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.34, 0.37,0.01))
plt.tight_layout()
plt.savefig('cm_ia.png',dpi=300)
plt.show()
print('angle mean: ' + str(np.mean(ia)) + ' sd: ' + str(np.std(ia)))
print('angle 95% CI : ' + str(np.percentile(ia,2.5)) + ',' + str(np.percentile(ia,97.5)))


plt.hist(ig,normed=True,range=[0.0,1.0],bins=60,alpha=0.8)
plt.xlim(0.0,1.0)
plt.xlabel('minimum interaction range')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.0, 1.0,0.25))
plt.tight_layout()
plt.savefig('cm_ig.png',dpi=300)
plt.show()
print('ignore mean: ' + str(np.mean(ig)) + ' sd: ' + str(np.std(ig)))
print('ignore 95% CI : ' + str(np.percentile(ig,2.5)) + ',' + str(np.percentile(ig,97.5)))

plt.hist(aw,normed=True,range=[0.9,1.75],bins=60,alpha=0.8)
plt.xlim(0.9,1.75)
plt.xlabel('minimum interaction range')
plt.ylabel('posterior density')
plt.xticks(np.arange(0.9, 1.75,0.25))
plt.tight_layout()
plt.savefig('cm_ig.png',dpi=300)
plt.show()
print('align mean: ' + str(np.mean(aw)) + ' sd: ' + str(np.std(aw)))
print('align 95% CI : ' + str(np.percentile(aw,2.5)) + ',' + str(np.percentile(aw,97.5)))
# Out:
# rho_m mean: 0.93917305067 sd: 0.000582497651554
# rho_m 95% CI : 0.93800906965,0.940286405962
# beta mean: 0.0769621430287 sd: 0.00370739725636
# beta 95% CI : 0.0696172849741,0.0841192049626
# alpha mean: 0.358399177281 sd: 0.00744262029285
# alpha 95% CI : 0.343943390671,0.373037319263
# length mean: 8.74085125682 sd: 0.00439421251755
# length 95% CI : 8.73386356317,8.74788895402
# angle mean: 0.360052821135 sd: 0.00280482673295
# angle 95% CI : 0.355040893516,0.364193860706
# ignore mean: 0.518667219013 sd: 0.0842752733136
# ignore 95% CI : 0.352565523456,0.736198938116
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:6016: RuntimeWarning: invalid value encountered in true_divide
#   m = (m.astype(float) / db) / m.sum()
# align mean: 2.45086317994 sd: 0.11250993898
# align 95% CI : 2.22580145226,2.66680054691

# %%
rho_s=np.load('mc_data/dm_rho_s.npy')
alpha=np.load('mc_data/dm_alpha.npy')
beta=np.load('mc_data/dm_beta.npy')

ia = np.load('mc_data/dm_ia.npy')
il = np.load('mc_data/dm_il.npy')
de = np.load('mc_data/dm_de.npy')
ig = np.load('mc_data/dm_ig.npy')

allData = [rho_s,alpha,ia,il,de,ig]

for i in range(len(allData)):
    
    pltThis = allData[i]
    xstart = np.mean(pltThis)-5*np.std(pltThis)
    xstop = np.mean(pltThis)+5*np.std(pltThis)
    X_plot = np.linspace(xstart, xstop, 1000)#[:, np.newaxis]
    log_dens = norm.pdf(X_plot,np.mean(pltThis),np.std(pltThis))
    plt.plot(X_plot, (log_dens),'k-',linewidth=2)
    plt.hist(pltThis,normed=True,range=[xstart,xstop],bins=50,alpha=0.4)
    plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

    plt.xlim(xstart,xstop)
    plt.show()
    plt.figure()

print('rho_s ' + str(np.mean(rho_s)))
print('alpha ' + str(np.mean(alpha)))
print('beta ' + str(np.mean(beta)))
print('ia ' + str(np.mean(ia)))
print('il ' + str(np.mean(il)))
print('de ' + str(np.mean(de)))
print('ig ' + str(np.mean(ig)))
# Out:
# rho_s 0.938345313949
# alpha 0.381300752698
# beta 0.0957352609029
# ia 0.251502817927
# il 8.38505277215
# de 22.1823783238
# ig 1.32785597351

# %%
rho_s=np.load('mc_data/dma_rho_s.npy')
alpha=np.load('mc_data/dma_alpha.npy')
beta=np.load('mc_data/dma_beta.npy')

ia = np.load('mc_data/dma_at_a.npy')
il = np.load('mc_data/dma_at_l.npy')
de = np.load('mc_data/dma_at_e.npy')
aw = np.load('mc_data/dma_aw.npy')
ig = np.load('mc_data/dma_ig.npy')

allData = [rho_s,alpha]#,beta,ia,il,aw,ig,de]

for i in range(len(allData)):
    
    pltThis = allData[i]
    xstart = np.mean(pltThis)-5*np.std(pltThis)
    xstop = np.mean(pltThis)+5*np.std(pltThis)
    X_plot = np.linspace(xstart, xstop, 1000)#[:, np.newaxis]
    log_dens = norm.pdf(X_plot,np.mean(pltThis),np.std(pltThis))
    plt.plot(X_plot, (log_dens),'k-',linewidth=2)
    plt.hist(pltThis,normed=True,range=[xstart,xstop],bins=50,alpha=0.4)
    plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

    plt.xlim(xstart,xstop)
    plt.show()
    plt.figure()

print('rho_s ' + str(np.mean(rho_s)))
print('alpha ' + str(np.mean(alpha)))
print('ia ' + str(np.mean(ia)))
print('il ' + str(np.mean(il)))
print('aw ' + str(np.mean(aw)))
print('ig ' + str(np.mean(ig)))
print('de ' + str(np.mean(de)))
# Out:
# rho_s 0.939644712413
# alpha 0.378453120147
# ia 0.280750608147
# il 3.40804482821
# aw 2.24663947036
# ig 0.52725339151
# de 3.50977235539

# %%
rho_s=np.load('mc_data/nm_rho_s.npy')
alpha=np.load('mc_data/nm_alpha.npy')

ia = np.load('mc_data/nm_ia.npy')
il = np.load('mc_data/nm_il.npy')
ig = np.load('mc_data/nm_ig.npy')

allData = [rho_s,alpha,ia,il,ig]

for i in range(len(allData)):
    
    pltThis = allData[i]
    xstart = np.mean(pltThis)-5*np.std(pltThis)
    xstop = np.mean(pltThis)+5*np.std(pltThis)
    X_plot = np.linspace(xstart, xstop, 1000)#[:, np.newaxis]
    log_dens = norm.pdf(X_plot,np.mean(pltThis),np.std(pltThis))
    plt.plot(X_plot, (log_dens),'k-',linewidth=2)
    plt.hist(pltThis,normed=True,range=[xstart,xstop],bins=50,alpha=0.4)
    plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

    plt.xlim(xstart,xstop)
    plt.show()
    plt.figure()

print('rho_s ' + str(np.mean(rho_s)))
print('alpha ' + str(np.mean(alpha)))
print('ia ' + str(np.mean(ia)))
print('il ' + str(np.mean(il)))
print('ig ' + str(np.mean(ig)))
# Out:
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:1580: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:1582: RuntimeWarning: invalid value encountered in greater_equal
#   cond1 = (scale > 0) & (x >= self.a) & (x <= self.b)
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:1582: RuntimeWarning: invalid value encountered in less_equal
#   cond1 = (scale > 0) & (x >= self.a) & (x <= self.b)
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:2787: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=2.0, right=2.0
#   'left=%s, right=%s') % (left, right))
# rho_s 0.937283911749
# alpha 0.238746164326
# ia 0.309078806451
# il 2.0
# ig 1.08297055717

# %%
rho_s=np.load('mc_data/nma_rho_s.npy')
alpha=np.load('mc_data/nma_alpha.npy')

ia = np.load('mc_data/nma_ia.npy')
il = np.load('mc_data/nma_il.npy')
aw = np.load('mc_data/nma_aw.npy')
ig = np.load('mc_data/nma_ig.npy')

allData = [rho_s,alpha,ia,il,aw,ig]

for i in range(len(allData)):
    
    pltThis = allData[i]
    xstart = np.mean(pltThis)-5*np.std(pltThis)
    xstop = np.mean(pltThis)+5*np.std(pltThis)
    X_plot = np.linspace(xstart, xstop, 1000)#[:, np.newaxis]
    log_dens = norm.pdf(X_plot,np.mean(pltThis),np.std(pltThis))
    plt.plot(X_plot, (log_dens),'k-',linewidth=2)
    plt.hist(pltThis,normed=True,range=[xstart,xstop],bins=50,alpha=0.4)
    plt.fill_between(X_plot,np.zeros_like(X_plot), log_dens,alpha=0.4)#, fc='#AAAAFF')

    plt.xlim(xstart,xstop)
    plt.show()
    plt.figure()

print('rho_s ' + str(np.mean(rho_s)))
print('alpha ' + str(np.mean(alpha)))
print('ia ' + str(np.mean(ia)))
print('il ' + str(np.mean(il)))
print('aw ' + str(np.mean(aw)))
print('ig ' + str(np.mean(ig)))
# Out:
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:1580: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:1582: RuntimeWarning: invalid value encountered in greater_equal
#   cond1 = (scale > 0) & (x >= self.a) & (x <= self.b)
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:1582: RuntimeWarning: invalid value encountered in less_equal
#   cond1 = (scale > 0) & (x >= self.a) & (x <= self.b)
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:2787: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1.0, right=1.0
#   'left=%s, right=%s') % (left, right))
# rho_s 0.939119415206
# alpha 0.303485219303
# ia 0.282656667018
# il 1.0
# aw 1.98525008462
# ig 0.619832447915
